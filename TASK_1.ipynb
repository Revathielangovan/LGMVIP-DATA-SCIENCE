# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-69b848de-35cb-4dd8-bdbe-1d6449aaeaf7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69b848de-35cb-4dd8-bdbe-1d6449aaeaf7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car.jpg to car.jpg

# %%
import matplotlib.image as mpimg
img=mpimg.imread("car.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7FCEB33168D0>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x7FCEB3397950>

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7FCEB32C1790>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7FCEB32CFD50>

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x7FCEB32DB8D0>
